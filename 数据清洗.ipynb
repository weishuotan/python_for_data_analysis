# %%
import numpy as np

# %%
import pandas as pd

# 读取CSV文件
data = pd.read_csv('./data/vehicleSalesData.csv',encoding = 'gbk')

data
# Out:
# C:\Users\86139\AppData\Local\Temp\ipykernel_8772\2116147748.py:4: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('./data/vehicleSalesData.csv',encoding = 'gbk')
#                     省份  月份         市                      县    年份  \
# 0      Shanxi Province   3  Shuozhou      shuoCity District  2013
# 1      Shanxi Province   3  jincheng          City District  2013
# 2      Shanxi Province  12  changzhi  changzhiCity District  2013
# 3      Shanxi Province  12  changzhi  changzhiCity District  2013
# 4      Shanxi Province  12  changzhi  changzhiCity District  2013
# ...                ...  ..       ...                    ...   ...
# 70353  Shanxi Province  11  yuncheng             hequcounty  2013
# 70354  Shanxi Province  11  yuncheng             hequcounty  2013
# 70355  Shanxi Province  11  yuncheng             hequcounty  2013
# 70356  Shanxi Province  11  yuncheng             hequcounty  2013
# ...

# %%
# 查看包含缺失值的行
data[data.isnull().any(axis=1)]
# Out:
#                     省份  月份         市                      县    年份  \
# 0      Shanxi Province   3  Shuozhou      shuoCity District  2013
# 1      Shanxi Province   3  jincheng          City District  2013
# 2      Shanxi Province  12  changzhi  changzhiCity District  2013
# 8      Shanxi Province  12  changzhi  changzhiCity District  2013
# 9      Shanxi Province  12  changzhi  changzhiCity District  2013
# ...                ...  ..       ...                    ...   ...
# 70332  Shanxi Province  11  yuncheng                 yongji  2013
# 70333  Shanxi Province  11  yuncheng                 yongji  2013
# 70334  Shanxi Province  11  yuncheng                 yongji  2013
# 70335  Shanxi Province  11  yuncheng                 yongji  2013
# 70339  Shanxi Province  11  yuncheng                 yongji  2013
#
#                车架号                                            COMPANY  \
# 0        LZW6450PF                 SAIC GM Wuling Automobile Co., Ltd
# ...

# %%
##  省份处理——发现没有缺失值
data[data['省份'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [省份, 月份, 市, 县, 年份, 车架号, COMPANY, 车系, 车型, 商用或个人, 用途, 销量, 发动机, 排量, 发动机参数1, 发动机参数2燃油类型, 发动机参数3, 发动机参数1.1, 发动机参数4, 生产商, 生产子COMPANY, 车机生产编号, 所属企业, 车属分类]
# Index: []
#
# [0 rows x 24 columns]

# %%
# 月份处理
data[data['月份'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [省份, 月份, 市, 县, 年份, 车架号, COMPANY, 车系, 车型, 商用或个人, 用途, 销量, 发动机, 排量, 发动机参数1, 发动机参数2燃油类型, 发动机参数3, 发动机参数1.1, 发动机参数4, 生产商, 生产子COMPANY, 车机生产编号, 所属企业, 车属分类]
# Index: []
#
# [0 rows x 24 columns]

# %%
data[data['月份']>12]
# Out:
# Empty DataFrame
# Columns: [省份, 月份, 市, 县, 年份, 车架号, COMPANY, 车系, 车型, 商用或个人, 用途, 销量, 发动机, 排量, 发动机参数1, 发动机参数2燃油类型, 发动机参数3, 发动机参数1.1, 发动机参数4, 生产商, 生产子COMPANY, 车机生产编号, 所属企业, 车属分类]
# Index: []
#
# [0 rows x 24 columns]

# %%
data[data['月份']<=0]
# Out:
# Empty DataFrame
# Columns: [省份, 月份, 市, 县, 年份, 车架号, COMPANY, 车系, 车型, 商用或个人, 用途, 销量, 发动机, 排量, 发动机参数1, 发动机参数2燃油类型, 发动机参数3, 发动机参数1.1, 发动机参数4, 生产商, 生产子COMPANY, 车机生产编号, 所属企业, 车属分类]
# Index: []
#
# [0 rows x 24 columns]

# %%
# 市，县处理
data[data['市'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [省份, 月份, 市, 县, 年份, 车架号, COMPANY, 车系, 车型, 商用或个人, 用途, 销量, 发动机, 排量, 发动机参数1, 发动机参数2燃油类型, 发动机参数3, 发动机参数1.1, 发动机参数4, 生产商, 生产子COMPANY, 车机生产编号, 所属企业, 车属分类]
# Index: []
#
# [0 rows x 24 columns]

# %%
data[data['县'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [省份, 月份, 市, 县, 年份, 车架号, COMPANY, 车系, 车型, 商用或个人, 用途, 销量, 发动机, 排量, 发动机参数1, 发动机参数2燃油类型, 发动机参数3, 发动机参数1.1, 发动机参数4, 生产商, 生产子COMPANY, 车机生产编号, 所属企业, 车属分类]
# Index: []
#
# [0 rows x 24 columns]

# %%
print(data['县'].value_counts())
# Out:
# 县
# CITYZONE         10339
# Taiyuan           7309
# 杏花岭区              3766
# City District     2600
# yanhu area        1616
#                  ...
# 右玉county            44
# 中阳county            38
# 黎城county            37
# 岚county             37
# 武乡county            15
# Name: count, Length: 120, dtype: int64

# %%
#年份处理  全部都是2013年
data[data['年份'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [省份, 月份, 市, 县, 年份, 车架号, COMPANY, 车系, 车型, 商用或个人, 用途, 销量, 发动机, 排量, 发动机参数1, 发动机参数2燃油类型, 发动机参数3, 发动机参数1.1, 发动机参数4, 生产商, 生产子COMPANY, 车机生产编号, 所属企业, 车属分类]
# Index: []
#
# [0 rows x 24 columns]

# %%
data[data['年份']==2013]
# Out:
#                     省份  月份         市                      县    年份  \
# 0      Shanxi Province   3  Shuozhou      shuoCity District  2013
# 1      Shanxi Province   3  jincheng          City District  2013
# 2      Shanxi Province  12  changzhi  changzhiCity District  2013
# 3      Shanxi Province  12  changzhi  changzhiCity District  2013
# 4      Shanxi Province  12  changzhi  changzhiCity District  2013
# ...                ...  ..       ...                    ...   ...
# 70353  Shanxi Province  11  yuncheng             hequcounty  2013
# 70354  Shanxi Province  11  yuncheng             hequcounty  2013
# 70355  Shanxi Province  11  yuncheng             hequcounty  2013
# 70356  Shanxi Province  11  yuncheng             hequcounty  2013
# 70357  Shanxi Province  11  yuncheng             hequcounty  2013
#
#                车架号                                   COMPANY        车系  \
# 0        LZW6450PF        SAIC GM Wuling Automobile Co., Ltd    WuLing
# ...

# %%
# 车架号
data['车架号'].value_counts()
# Out:
# 车架号
# LZW6376NF     13727
# LZW6407BAF     6357
# LZW6390QF      5967
# LZW6388NF      5120
# LZW6432KF      4097
#               ...
# CC6690KM09        1
# DFA6920T3B        1
# XMQ6859Y5         1
# JNP6110T          1
# EQ6790PT3         1
# Name: count, Length: 1049, dtype: int64

# %%
data[data['车架号'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [省份, 月份, 市, 县, 年份, 车架号, COMPANY, 车系, 车型, 商用或个人, 用途, 销量, 发动机, 排量, 发动机参数1, 发动机参数2燃油类型, 发动机参数3, 发动机参数1.1, 发动机参数4, 生产商, 生产子COMPANY, 车机生产编号, 所属企业, 车属分类]
# Index: []
#
# [0 rows x 24 columns]

# %%
#销量
data[data['销量'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [省份, 月份, 市, 县, 年份, 车架号, COMPANY, 车系, 车型, 商用或个人, 用途, 销量, 发动机, 排量, 发动机参数1, 发动机参数2燃油类型, 发动机参数3, 发动机参数1.1, 发动机参数4, 生产商, 生产子COMPANY, 车机生产编号, 所属企业, 车属分类]
# Index: []
#
# [0 rows x 24 columns]

# %%
df=data['销量']
df.sort_values()
# Out:
# 28654     1000
# 54147     1000
# 36065     1000
# 21632     1000
# 62057     1000
#          ...
# 64292     9999
# 30026    10000
# 27700    10000
# 27944    10000
# 36563    10000
# Name: 销量, Length: 70358, dtype: int64

# %%
#排量处理
print(data['排量'].unique())
# Out:
# ['8424' '1587' '1500' '1499' '1299' '1300' '1200' '1206' '2776' '11596'
#  '2402' '6500' '3759' '998' '995' '1485' '2499' '1243' '999' '1298' '3956'
#  '1997' '7140' '2982' '4214' '997' '1000' '1399' '1488' '1173' '970'
#  '1244' '1370' '2659' '2143' '2771' '6454' '6494' '1199' '1998' '1050'
#  '2798' '2498' '5200' '7800' '2295' '2953' '1210' '4760' '2694' '2998'
#  '1497' '3857' '4260' '5975' '1375' '977' '5202' '3707' '2438' '2020'
#  '4200' '3760' '3856' '1053' '1590' '9726' '2693' '3660' '7255' '4257'
#  '3298' '2351' '1205' '6750' '2496' '4730' '10338' '4500' '2156' '2999'
#  '6618' '2237' '1977' '2951' '2388' '1342' '11946' '4040' '3168' '5900'
#  '1809' '8900' '2540' '2500' '1598' '6230' '5130' '10520' '3922' '6700'
#  '6740' '3700' '2952' '8600' nan '7700' '1149' '1810' '8270' '797' '5883'
#  '5890' '2800' '11810' '2378' '9839' '2660' '1012' '3900' '5638' '1971'
#  '4752' '2400' '2010' '2672' '2384' '7146' '6234' '5420' '3153' '1372'
# ...

# %%
data[data['排量'].isnull()==True]
# Out:
#                     省份  月份         市         县    年份          车架号  \
# 12502  Shanxi Province   3  Shuozhou  山阴county  2013  LCK6121HEV1
# 12503  Shanxi Province   3  Shuozhou  山阴county  2013  LCK6121HEV1
# 12504  Shanxi Province   3  Shuozhou  山阴county  2013  LCK6121HEV1
# 12505  Shanxi Province   3  Shuozhou  山阴county  2013  LCK6121HEV1
# 12506  Shanxi Province   3  Shuozhou  山阴county  2013  LCK6121HEV1
# ...                ...  ..       ...       ...   ...          ...
# 26205  Shanxi Province   4    Linfen    Linfen  2013  CNJ6850JQNM
# 26206  Shanxi Province   4    Linfen    Linfen  2013  CNJ6850JQNM
# 26214  Shanxi Province   4  jincheng  jincheng  2013   DLQ6600EA3
# 26215  Shanxi Province   4  jincheng  jincheng  2013   DLQ6600EA3
# 26551  Shanxi Province   4   xinzhou   xinzhou  2013  EQ6400LF22Q
#
#                               COMPANY         车系                  车型 商用或个人  \
# 12502  Zhongtong bus Holding Co., Ltd  zhongtong  Large ordinary bus  unit
# ...

# %%
data = data.dropna(subset=['排量'])

# %%
print(data['排量'].unique())
# Out:
# ['8424' '1587' '1500' '1499' '1299' '1300' '1200' '1206' '2776' '11596'
#  '2402' '6500' '3759' '998' '995' '1485' '2499' '1243' '999' '1298' '3956'
#  '1997' '7140' '2982' '4214' '997' '1000' '1399' '1488' '1173' '970'
#  '1244' '1370' '2659' '2143' '2771' '6454' '6494' '1199' '1998' '1050'
#  '2798' '2498' '5200' '7800' '2295' '2953' '1210' '4760' '2694' '2998'
#  '1497' '3857' '4260' '5975' '1375' '977' '5202' '3707' '2438' '2020'
#  '4200' '3760' '3856' '1053' '1590' '9726' '2693' '3660' '7255' '4257'
#  '3298' '2351' '1205' '6750' '2496' '4730' '10338' '4500' '2156' '2999'
#  '6618' '2237' '1977' '2951' '2388' '1342' '11946' '4040' '3168' '5900'
#  '1809' '8900' '2540' '2500' '1598' '6230' '5130' '10520' '3922' '6700'
#  '6740' '3700' '2952' '8600' '7700' '1149' '1810' '8270' '797' '5883'
#  '5890' '2800' '11810' '2378' '9839' '2660' '1012' '3900' '5638' '1971'
#  '4752' '2400' '2010' '2672' '2384' '7146' '6234' '5420' '3153' '1372'
# ...

# %%
#车型
data['车型'].value_counts()
# Out:
# 车型
# Small passenger car    51355
# SMNOT                  10796
# Large ordinary bus      2309
# Medium sized coach      1114
# BINORKK                  793
# NOXNORKK                 280
# bigSchoolBus             221
# NOXZYSCHOOLBUS            29
# 小型ZYKK                     5
# BI铰接KK                     3
# 微型NORKK                    2
# NOX越野KK                    1
# BI双层KK                     1
# Name: count, dtype: int64

# %%
data[data['车型'].isnull()==True]
# Out:
#                     省份  月份         市               县    年份        车架号  \
# 29785  Shanxi Province   1    Linfen        浮山county  2013  LZW6431MF
# 29786  Shanxi Province   1  Jinzhong        和顺county  2013  LZW6431MF
# 29787  Shanxi Province   1  yuncheng        平陆county  2013  LZW6431MF
# 29788  Shanxi Province   1  Jinzhong        和顺county  2013  LZW6431MF
# 29789  Shanxi Province   1  Shuozhou             平鲁区  2013  LZW6431MF
# ...                ...  ..       ...             ...   ...        ...
# 33051  Shanxi Province   3  yuncheng  wangrongcounty  2013    SC6449C
# 33052  Shanxi Province   3  yuncheng        yuncheng  2013    SC6449C
# 33053  Shanxi Province   3    datong          datong  2013    SC6449C
# 33054  Shanxi Province   3    Linfen             侯马市  2013    SC6449C
# 33055  Shanxi Province   3   xinzhou         xinzhou  2013    SC6449C
#
#            COMPANY               车系   车型     商用或个人  ... 发动机参数1  发动机参数2燃油类型  \
# ...

# %%
pd.savefig('./data2/vehicleSalesData.csv')
