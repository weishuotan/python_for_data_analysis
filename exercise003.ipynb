# %%
pip install scikit-learn==1.4.2 -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#      - -------------------------------------- 0.3/10.6 MB 9.6 MB/s eta 0:00:02
#      - -------------------------------------- 0.5/10.6 MB 6.3 MB/s eta 0:00:02
#      --- ------------------------------------ 0.8/10.6 MB 6.4 MB/s eta 0:00:02
#      ----- ---------------------------------- 1.4/10.6 MB 8.0 MB/s eta 0:00:02
#      -------- ------------------------------- 2.3/10.6 MB 10.4 MB/s eta 0:00:01
#      ----------- ---------------------------- 3.0/10.6 MB 11.1 MB/s eta 0:00:01
#      ------------ --------------------------- 3.2/10.6 MB 10.7 MB/s eta 0:00:01
#      -------------- ------------------------- 3.8/10.6 MB 11.0 MB/s eta 0:00:01
#      --------------- ------------------------ 4.1/10.6 MB 10.6 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import mpl
from wordcloud import WordCloud
mpl.rcParams['font.sans-serif']=['SimHei']
import csv
import math

# %%
data = pd.read_csv('./data/Mall_Customers.csv')

data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
#列名重命名
data.rename(columns={'Annual Income (k$)':'A_Income',
                    'Spending Score (1-100)':'Score'},inplace=True)

# %%
data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'A_Income', 'Score'], dtype='object')

# %%
new_data=data.drop(['CustomerID','Gender'],axis=1)
new_data
# Out:
#      Age  A_Income  Score
# 0     19        15     39
# 1     21        15     81
# 2     20        16      6
# 3     23        16     77
# 4     31        17     40
# ..   ...       ...    ...
# 195   35       120     79
# 196   45       126     28
# 197   32       126     74
# 198   32       137     18
# 199   30       137     83
#
# [200 rows x 3 columns]

# %%
plt.figure(figsize=(5,3))
sns.histplot(data['Age'],kde=True)
plt.xlabel('Age')
plt.show()

# %%
km1=KMeans(n_clusters=1).fit(new_data)#创建一个K-Means聚类模型实例，，并指定聚类的数量，指定数据来训练

new_data['Labels']=km1.labels_#获取km1模型训练后每个数据点所属的簇标签

plt.figure(figsize=(12,8))
sns.scatterplot(x=new_data['A_Income'],y=new_data['Score'],hue=new_data['Labels'],
                palette=sns.color_palette('hls',3))#使用三种颜色
plt.title('KMeans with 1 Cluster')
plt.show()

# %%
km2=KMeans(n_clusters=2).fit(new_data)#创建一个K-Means聚类模型实例，，并指定聚类的数量，指定数据来训练

new_data['Labels']=km2.labels_#获取km1模型训练后每个数据点所属的簇标签

plt.figure(figsize=(12,8))
sns.scatterplot(x=new_data['A_Income'],y=new_data['Score'],hue=new_data['Labels'],
                palette=sns.color_palette('hls',3))#使用三种颜色
plt.title('KMeans with 2 Cluster')
plt.show()

# %%
km3=KMeans(n_clusters=3).fit(new_data)#创建一个K-Means聚类模型实例，，并指定聚类的数量，指定数据来训练

new_data['Labels']=km3.labels_#获取km1模型训练后每个数据点所属的簇标签

plt.figure(figsize=(12,8))
sns.scatterplot(x=new_data['A_Income'],y=new_data['Score'],hue=new_data['Labels'],
                palette=sns.color_palette('hls',3))#使用三种颜色
plt.title('KMeans with 3 Cluster')
plt.show()

# %%
km5=KMeans(n_clusters=5).fit(new_data)#创建一个K-Means聚类模型实例，，并指定聚类的数量，指定数据来训练

new_data['Labels']=km5.labels_#获取km1模型训练后每个数据点所属的簇标签

plt.figure(figsize=(12,8))
sns.scatterplot(x=new_data['A_Income'],y=new_data['Score'],hue=new_data['Labels'],
                palette=sns.color_palette('hls',5))#使用三种颜色
plt.title('KMeans with 5 Cluster')
plt.show()

# %%
km6=KMeans(n_clusters=6).fit(new_data)#创建一个K-Means聚类模型实例，，并指定聚类的数量，指定数据来训练

new_data['Labels']=km6.labels_#获取km1模型训练后每个数据点所属的簇标签

plt.figure(figsize=(12,8))
sns.scatterplot(x=new_data['A_Income'],y=new_data['Score'],hue=new_data['Labels'],
                palette=sns.color_palette('hls',6))#使用三种颜色
plt.title('KMeans with 6 Cluster')
plt.show()

# %%
km7=KMeans(n_clusters=7).fit(new_data)#创建一个K-Means聚类模型实例，，并指定聚类的数量，指定数据来训练

new_data['Labels']=km7.labels_#获取km1模型训练后每个数据点所属的簇标签

plt.figure(figsize=(12,8))
sns.scatterplot(x=new_data['A_Income'],y=new_data['Score'],hue=new_data['Labels'],
                palette=sns.color_palette('hls',7))#使用三种颜色
plt.title('KMeans with 7 Cluster')
plt.show()

# %%
km7=KMeans(n_clusters=7).fit(new_data)#创建一个K-Means聚类模型实例，，并指定聚类的数量，指定数据来训练

new_data['Labels']=km7.labels_#获取km1模型训练后每个数据点所属的簇标签

plt.figure(figsize=(12,8))
sns.scatterplot(x=new_data['Age'],y=new_data['Score'],hue=new_data['Labels'],
                palette=sns.color_palette('hls',7))#使用三种颜色
plt.title('KMeans with 7 Cluster')
plt.show()

# %%
km32=KMeans(n_clusters=3).fit(new_data)#创建一个K-Means聚类模型实例，，并指定聚类的数量，指定数据来训练

new_data['Labels']=km32.labels_#获取km1模型训练后每个数据点所属的簇标签

plt.figure(figsize=(12,8))
sns.scatterplot(x=new_data['Age'],y=new_data['Score'],hue=new_data['Labels'],
                palette=sns.color_palette('hls',3))#使用三种颜色
plt.title('KMeans with 3 Cluster')
plt.show()

# %%
km42=KMeans(n_clusters=4).fit(new_data)#创建一个K-Means聚类模型实例，，并指定聚类的数量，指定数据来训练

new_data['Labels']=km42.labels_#获取km1模型训练后每个数据点所属的簇标签

plt.figure(figsize=(12,8))
sns.scatterplot(x=new_data['Age'],y=new_data['Score'],hue=new_data['Labels'],
                palette=sns.color_palette('hls',4))#使用三种颜色
plt.title('KMeans with 4 Cluster')
plt.show()

# %%
km22=KMeans(n_clusters=2).fit(new_data)#创建一个K-Means聚类模型实例，，并指定聚类的数量，指定数据来训练

new_data['Labels']=km22.labels_#获取km1模型训练后每个数据点所属的簇标签

plt.figure(figsize=(12,8))
sns.scatterplot(x=new_data['Age'],y=new_data['Score'],hue=new_data['Labels'],
                palette=sns.color_palette('hls',2))#使用三种颜色
plt.title('KMeans with 2 Cluster')
plt.show()

# %%
km62=KMeans(n_clusters=6).fit(new_data)#创建一个K-Means聚类模型实例，，并指定聚类的数量，指定数据来训练

new_data['Labels']=km62.labels_#获取km1模型训练后每个数据点所属的簇标签

plt.figure(figsize=(12,8))
sns.scatterplot(x=new_data['Age'],y=new_data['Score'],hue=new_data['Labels'],
                palette=sns.color_palette('hls',6))#使用三种颜色
plt.title('KMeans with 6 Cluster')
plt.show()

# %%
km3=KMeans(n_clusters=3).fit(new_data)#创建一个K-Means聚类模型实例，，并指定聚类的数量，指定数据来训练

new_data['Labels']=km3.labels_#获取km1模型训练后每个数据点所属的簇标签

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.cluster import KMeans 
#获取特征数据
x= new_data['Age']
y=new_data['A_Income'] 
strength=new_data['Score'] 
labels= new_data['Labels'] 
#绘制制教点图
plt.figure(figsize=(10,6)) 
scatter=plt.scatter(x,y, c=labels, cmap='coolwarm',s=strength, alpha=0.7) 
plt.colorbar(scatter,label='Cluster Label') 
plt.xlabel('Age') 
plt.ylabel('Annual Income(k$)') 
plt.title('Cluster Analysis by Age, AnnuaIncpending Score')
plt.show()

# %%
km7=KMeans(n_clusters=7).fit(new_data)#创建一个K-Means聚类模型实例，，并指定聚类的数量，指定数据来训练

new_data['Labels']=km7.labels_#获取km1模型训练后每个数据点所属的簇标签

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.cluster import KMeans 
#获取特征数据
x= new_data['Age']
y=new_data['A_Income'] 
strength=new_data['Score'] 
labels= new_data['Labels'] 
#绘制制教点图
plt.figure(figsize=(10,6)) 
scatter=plt.scatter(x,y, c=labels, cmap='coolwarm',s=strength, alpha=0.7) 
plt.colorbar(scatter,label='Cluster Label') 
plt.xlabel('Age') 
plt.ylabel('Annual Income(k$)') 
plt.title('Cluster Analysis by Age, AnnuaIncpending Score,n_clusters=7')
plt.show()

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.cluster import KMeans 
#获取特征数据
y= new_data['Age']
x=new_data['A_Income'] 
strength=new_data['Score'] 
labels= new_data['Labels'] 
#绘制制教点图
plt.figure(figsize=(10,6)) 
scatter=plt.scatter(x,y, c=labels, cmap='coolwarm',s=strength, alpha=0.7) 
plt.colorbar(scatter,label='Cluster Label') 
plt.xlabel('Annual Income(k$)') 
plt.ylabel('Age') 
plt.title('Cluster Analysis by Age, AnnuaIncpending Score,n_clusters=7')
plt.show()

# %%
from sklearn.metrics import silhouette_score

# %% [markdown]
# ##  算法评估（肘部法、轮廓系数）

# %%
#准备数据
x1 = data[['Age','A_Income','Score']].iloc[:,:].values

silhouette_scores=[]

for n in range(2,11):
    algorithm = (KMeans(n_clusters = n,init = 'k-means++',
                        n_init = 10,max_iter = 100,tol = 0.0001,random_state = 111,algorithm = 'lloyd'))
    labels=algorithm.fit_predict(x1)
    silhouette_avg=silhouette_score(x1,labels)
    silhouette_scores.append(silhouette_avg)

# %%
plt.figure(figsize=(12,6))
plt.plot(range(2,11),silhouette_scores,marker='*')
plt.xlabel('Number of clusters')
plt.ylabel('silhouette score')
plt.title("silhouette score for optimal clustering")
plt.show()

# %%
x1 = data[['Age','A_Income','Score']].iloc[:,:].values
inertia = []
for n in range(1,11):
    algorithm = (KMeans(n_clusters = n,init = 'k-means++',
                        n_init = 10,max_iter = 100,tol = 0.0001,random_state = 111,algorithm = 'lloyd'))
    algorithm.fit(x1)
    inertia.append(algorithm.inertia_)

# %%
plt.figure(1,figsize = (12,6))
plt.plot(np.arange(1,11),inertia,'o')
plt.plot(np.arange(1,11),inertia,'-',alpha = 0.5)
plt.xlabel('Number of Clusters')
plt.ylabel('Inertai')
plt.show()
